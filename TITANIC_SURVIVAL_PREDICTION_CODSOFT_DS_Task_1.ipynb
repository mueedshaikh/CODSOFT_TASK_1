# %% [markdown]
# **1. Import the relevant python libraries for the analysis**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image, display
# %matplotlib inline

# %% [markdown]
# **2. Load the train and test dataset and set the index if applicable**

# %%
#load the train dataset
train = pd.read_csv('/content/Titanic-Dataset.csv')

# %%
#inspect the first few rows of the train dataset
display(train.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# set the index to passengerId
train = train.set_index('PassengerId')

# %%
#load the test dataset
test = pd.read_csv('/content/Titanic-Dataset.csv')

# %%
#inspect the first few rows of the test dataset
display(test.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **3. Visually inspect the head of the dataset,Examine the train dataset to understand in particular if the data is tidy, shape of the dataset,examine datatypes, examine missing values, unique counts and build a data dictionary dataframe**

# %% [markdown]
# Conditions to check if **data is tidy**
#
#
# *  Is every column a variable?
#
# *  Is every row an observation?
# *  Is every table a single observational unit?

# %%
#by calling the shape attribute of the train dataset we can observe that there are 891 observations and 11 columns
#in the data set
train.shape
# Out:
# (891, 11)

# %%
# Check out the data summary
# Age, Cabin and Embarked has missing data
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
# @title Age vs SibSp

from matplotlib import pyplot as plt
train.plot(kind='scatter', x='Age', y='SibSp', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Age vs Fare

import matplotlib.pyplot as plt

# Create scatter plot
plt.scatter(train['Age'], train['Fare'], c=train['Pclass'])

# Set labels and title
plt.xlabel('Age')
plt.ylabel('Fare')
_ = plt.title('Age vs Fare')

# %%
# @title Embarked

from matplotlib import pyplot as plt
import seaborn as sns
train.groupby('Embarked').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Pclass

from matplotlib import pyplot as plt
train['Pclass'].plot(kind='hist', bins=20, title='Pclass')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Survived

from matplotlib import pyplot as plt
train['Survived'].plot(kind='hist', bins=20, title='Survived')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Embarked vs Pclass

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (8, 1 * len(train['Embarked'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(train, x='Pclass', y='Embarked', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-18-d999f3d72b8a>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(train, x='Pclass', y='Embarked', inner='box', palette='Dark2')

# %%
# @title Sex vs Pclass

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (8, 1 * len(train['Sex'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(train, x='Pclass', y='Sex', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-19-a712f67752c2>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(train, x='Pclass', y='Sex', inner='box', palette='Dark2')

# %%
# @title Embarked vs Survived

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (8, 1 * len(train['Embarked'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(train, x='Survived', y='Embarked', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-20-f3b95dfa5fc8>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(train, x='Survived', y='Embarked', inner='box', palette='Dark2')

# %%
# @title Sex vs Survived

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (8, 1 * len(train['Sex'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(train, x='Survived', y='Sex', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-21-c4001a341a88>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(train, x='Survived', y='Sex', inner='box', palette='Dark2')

# %%
# @title Sex vs Embarked

from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(6, 6))
df_2dhist = pd.DataFrame({
    x_label: grp['Embarked'].value_counts()
    for x_label, grp in train.groupby('Sex')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Sex')
_ = plt.ylabel('Embarked')

# %%
# @title SibSp

from matplotlib import pyplot as plt
train['SibSp'].plot(kind='line', figsize=(8, 4), title='SibSp')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title Age

from matplotlib import pyplot as plt
train['Age'].plot(kind='line', figsize=(8, 4), title='Age')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title Pclass

from matplotlib import pyplot as plt
train['Pclass'].plot(kind='line', figsize=(8, 4), title='Pclass')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title Survived

from matplotlib import pyplot as plt
train['Survived'].plot(kind='line', figsize=(8, 4), title='Survived')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title SibSp vs Parch

from matplotlib import pyplot as plt
train.plot(kind='scatter', x='SibSp', y='Parch', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Age vs SibSp

from matplotlib import pyplot as plt
train.plot(kind='scatter', x='Age', y='SibSp', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Pclass vs Age

from matplotlib import pyplot as plt
train.plot(kind='scatter', x='Pclass', y='Age', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Survived vs Pclass

from matplotlib import pyplot as plt
train.plot(kind='scatter', x='Survived', y='Pclass', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Embarked

from matplotlib import pyplot as plt
import seaborn as sns
train.groupby('Embarked').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Sex

from matplotlib import pyplot as plt
import seaborn as sns
train.groupby('Sex').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title SibSp

from matplotlib import pyplot as plt
train['SibSp'].plot(kind='hist', bins=20, title='SibSp')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Age

from matplotlib import pyplot as plt
train['Age'].plot(kind='hist', bins=20, title='Age')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Pclass

from matplotlib import pyplot as plt
train['Pclass'].plot(kind='hist', bins=20, title='Pclass')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Survived

from matplotlib import pyplot as plt
train['Survived'].plot(kind='hist', bins=20, title='Survived')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# identify datatypes of the 11 columns, add the stats to the datadict
datadict = pd.DataFrame(train.dtypes)
datadict
# Out:
#                 0
# Survived    int64
# Pclass      int64
# Name       object
# Sex        object
# Age       float64
# SibSp       int64
# Parch       int64
# Ticket     object
# Fare      float64
# Cabin      object
# Embarked   object
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# datadict.groupby(0).size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# identify missing values of the 11 columns,add the stats to the datadict
datadict['MissingVal'] = train.isnull().sum()
datadict
# Out:
#                 0  MissingVal
# Survived    int64           0
# Pclass      int64           0
# Name       object           0
# Sex        object           0
# Age       float64         177
# SibSp       int64           0
# Parch       int64           0
# Ticket     object           0
# Fare      float64           0
# Cabin      object         687
# Embarked   object           2

# %%
# @title MissingVal

from matplotlib import pyplot as plt
datadict['MissingVal'].plot(kind='line', figsize=(8, 4), title='MissingVal')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# Identify number of unique values, For object nunique will the number of levels
# Add the stats the data dict
datadict['NUnique']=train.nunique()
datadict
# Out:
#                 0  MissingVal  NUnique
# Survived    int64           0        2
# Pclass      int64           0        3
# Name       object           0      891
# Sex        object           0        2
# Age       float64         177       88
# SibSp       int64           0        7
# Parch       int64           0        7
# Ticket     object           0      681
# Fare      float64           0      248
# Cabin      object         687      147
# Embarked   object           2        3

# %%
# @title NUnique

from matplotlib import pyplot as plt
datadict['NUnique'].plot(kind='line', figsize=(8, 4), title='NUnique')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# Identify the count for each variable, add the stats to datadict
datadict['Count']=train.count()
datadict
# Out:
#                 0  MissingVal  NUnique  Count
# Survived    int64           0        2    891
# Pclass      int64           0        3    891
# Name       object           0      891    891
# Sex        object           0        2    891
# Age       float64         177       88    714
# SibSp       int64           0        7    891
# Parch       int64           0        7    891
# Ticket     object           0      681    891
# Fare      float64           0      248    891
# Cabin      object         687      147    204
# Embarked   object           2        3    889

# %%
# @title Count

from matplotlib import pyplot as plt
datadict['Count'].plot(kind='line', figsize=(8, 4), title='Count')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# rename the 0 column
datadict = datadict.rename(columns={0:'DataType'})
datadict
# Out:
#          DataType  MissingVal  NUnique  Count
# Survived    int64           0        2    891
# Pclass      int64           0        3    891
# Name       object           0      891    891
# Sex        object           0        2    891
# Age       float64         177       88    714
# SibSp       int64           0        7    891
# Parch       int64           0        7    891
# Ticket     object           0      681    891
# Fare      float64           0      248    891
# Cabin      object         687      147    204
# Embarked   object           2        3    889

# %% [markdown]
# **4. Run discriptive statistics of object and numerical datatypes, and finally transform datatypes accoringly**

# %%
# get discripte statistcs on "object" datatypes
train.describe(include=['object'])
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
# get discriptive statistcs on "number" datatypes
train.describe(include=['number'])
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# **5. Carryout univariate and multivariate analysis using graphical and non graphical(some numbers represting the data)**

# %%
train.Survived.value_counts(normalize=True)
# Out:
# Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %% [markdown]
# only 38% of the passengers were survived, where as a majority 61% the passenger did not survive the disaster

# %% [markdown]
# **Univariate Analysis**

# %%
fig, axes = plt.subplots(2, 4, figsize=(16, 10))
#sns.countplot('Survived',data=train,ax=axes[0,0])
sns.countplot('Survived', ax=axes[0, 0])
sns.countplot('Pclass', ax=axes[0, 1])
sns.countplot('Sex', ax=axes[0, 2])
sns.countplot('SibSp', ax=axes[0, 3])
sns.countplot('Parch', ax=axes[1, 0])
sns.countplot('Embarked', ax=axes[1, 1])
sns.distplot(train['Fare'], kde=True, ax=axes[1, 2])
sns.distplot(train['Age'].dropna(), kde=True, ax=axes[1, 3])
# Out:
# <ipython-input-50-e9695fffa49e>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['Fare'], kde=True, ax=axes[1, 2])
# <ipython-input-50-e9695fffa49e>:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['Age'].dropna(), kde=True, ax=axes[1, 3])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# **6. Bivariate EDA**

# %% [markdown]
# We can clearly see that male survial rates is around 20% where as female survial rate is about 75% which suggests that gender has a strong relationship with the survival rates.
#
#  Here is also a clear relationship between Pclass and the survival by referring to first plot below. Passengers on Pclass1 had a better survial rate of approx 60% whereas passengers on pclass3 had the worst survial rate of approx 22%
#
#  There is also a marginal relationship between the fare and survial rate.
#
#  I have quantified the above relationships further in the last statsical modelling section

# %%
figbi, axesbi = plt.subplots(2, 4, figsize=(16, 10))
train.groupby('Pclass')['Survived'].mean().plot(kind='barh',ax=axesbi[0,0],xlim=[0,1])
train.groupby('SibSp')['Survived'].mean().plot(kind='barh',ax=axesbi[0,1],xlim=[0,1])
train.groupby('Parch')['Survived'].mean().plot(kind='barh',ax=axesbi[0,2],xlim=[0,1])
train.groupby('Sex')['Survived'].mean().plot(kind='barh',ax=axesbi[0,3],xlim=[0,1])
train.groupby('Embarked')['Survived'].mean().plot(kind='barh',ax=axesbi[1,0],xlim=[0,1])
sns.boxplot(x="Survived", y="Age", data=train,ax=axesbi[1,1])
sns.boxplot(x="Survived", y="Fare", data=train,ax=axesbi[1,2])
# Out:
# <Axes: xlabel='Survived', ylabel='Fare'>

# %% [markdown]
# Joint Plots(continous vs continous)

# %%
sns.jointplot(x="Age", y="Fare", data=train);

# %% [markdown]
# **7. Feature Engineering Data- Extract title from name, Extract new features from the other features**

# %%
train['Ticket_First']=train.Ticket.str[0]

# %%
train['FamilyCount']=train.SibSp+train.Parch

# %%
train['Cabin_First']=train.Cabin.str[0]

# %% [markdown]
# **8. Preprocessing and Prepare data for statistical modeling.**
#
#  **a. Imput Missing or Zero values to the Fare variable**

# %%
# we see that there are 15 Zero values and its reasonbale
# to flag them as missing values since every ticket
# should have a value greater than 0
print((train.Fare == 0).sum())
# Out:
# 15

# %%
# mark zero values as missing or NaN
train.Fare = train.Fare.replace(0, np.NaN)

# %%
# validate to see if there are no more zero values
print((train.Fare == 0).sum())
# Out:
# 0

# %%
# keep the index
train[train.Fare.isnull()].index
# Out:
# Index([180, 264, 272, 278, 303, 414, 467, 482, 598, 634, 675, 733, 807, 816,
#        823],
#       dtype='int64', name='PassengerId')

# %%
train.Fare.mean()
# Out:
# 32.75564988584475

# %% [markdown]
# Having missing values in a dataset can cause errors with some machine learning algorithms and either the rows that has missing values should be removed or imputed

# %% [markdown]
# Imputing refers to using a model to replace missing values.

# %% [markdown]
# There are many options we could consider when replacing a missing value, for example:

# %% [markdown]
#    *constant value that has meaning within the domain, such as 0, distinct from all other values.
#
#    *value from another randomly selected record.
#
#    *mean, median or mode value for the column.
#
#    *value estimated by another predictive model.

# %%
# impute the missing Fare values with the mean Fare value
train.Fare.fillna(train.Fare.mean(),inplace=True)

# %%
# validate if any null values are present after the imputation
train[train.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Ticket_First, FamilyCount, Cabin_First]
# Index: []

# %% [markdown]
# **b. Imput Missing or Zero values to the Age variable**

# %%
# we see that there are 0 Zero values
print((train.Age == 0).sum())
# Out:
# 0

# %%
# impute the missing Age values with the mean Fare value
train.Age.fillna(train.Age.mean(),inplace=True)

# %%
# validate if any null values are present after the imputation
train[train.Age.isnull()]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Ticket_First, FamilyCount, Cabin_First]
# Index: []

# %% [markdown]
# **c. Imput Missing or Zero values to the Cabin variable**

# %%
# We see that a majority 77% of the Cabin variable has missing values.
# Hence will drop the column from training a machine learnign algorithem
train.Cabin.isnull().mean()
# Out:
# 0.7710437710437711

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 1 to 891
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Survived      891 non-null    int64
#  1   Pclass        891 non-null    int64
#  2   Name          891 non-null    object
#  3   Sex           891 non-null    object
#  4   Age           891 non-null    float64
#  5   SibSp         891 non-null    int64
#  6   Parch         891 non-null    int64
#  7   Ticket        891 non-null    object
#  8   Fare          891 non-null    float64
#  9   Cabin         204 non-null    object
#  10  Embarked      889 non-null    object
#  11  Ticket_First  891 non-null    object
#  12  FamilyCount   891 non-null    int64
#  13  Cabin_First   204 non-null    object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 136.7+ KB

# %% [markdown]
# **9. Statistical Modelling**

# %%
train.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'Ticket_First', 'FamilyCount',
#        'Cabin_First'],
#       dtype='object')

# %%
trainML = train[['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
       'Fare', 'Embarked', 'Ticket_First', 'FamilyCount', 'Cabin_First']]

# %%
# drop rows of missing values
trainML = trainML.dropna()

# %%
# check the datafram has any missing values
trainML.isnull().sum()
# Out:
# Survived        0
# Pclass          0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Embarked        0
# Ticket_First    0
# FamilyCount     0
# Cabin_First     0
# dtype: int64

# %% [markdown]
# **A single predictor model with logistic regression**

# %% [markdown]
# we use logistic regression as the response variable is a binary classification

# %% [markdown]
# **Regression on survival on Age**

# %%
# Import Estimator AND Instantiate estimator class to create an estimator object
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
X_Age = trainML[['Age']].values
y = trainML['Survived'].values
# Use the fit method to train
lr.fit(X_Age,y)
# Make a prediction
y_predict = lr.predict(X_Age)
y_predict[:10]
(y == y_predict).mean()
# Out:
# 0.6831683168316832

# %% [markdown]
# The prediction accuracy is marginally better than the base line accuracy of 61.5% which we got earlier

# %% [markdown]
# **Regression on survival on Fare**

# %%
X_Fare = trainML[['Fare']].values
y = trainML['Survived'].values
# Use the fit method to train
lr.fit(X_Fare,y)
# Make a prediction
y_predict = lr.predict(X_Fare)
y_predict[:10]
(y == y_predict).mean()
# Out:
# 0.6633663366336634

# %% [markdown]
# The prediction accuracy got a bit better than the Age variable and much better than 61.5% base accuracy

# %% [markdown]
# **Regression on survive on Sex(using a Categorical Variable)**

# %%
X_sex = pd.get_dummies(trainML['Sex']).values
y = trainML['Survived'].values
# Use the fit method to train
lr.fit(X_sex, y)
# Make a prediction
y_predict = lr.predict(X_sex)
y_predict[:10]
(y == y_predict).mean()
# Out:
# 0.7475247524752475

# %% [markdown]
# The gender of passenger is a strong predictor and purely predciting based on gender, the model accuracy increased to 74%

# %% [markdown]
# **Regression on survive on PClass(using a Categorical Variable)**

# %%
X_pclass = pd.get_dummies(trainML['Pclass']).values
y = trainML['Survived'].values
lr = LogisticRegression()
lr.fit(X_pclass, y)
# Make a prediction
y_predict = lr.predict(X_pclass)
y_predict[:10]
(y == y_predict).mean()
# Out:
# 0.6633663366336634

# %% [markdown]
# Gender of the passenger seems a strong predictor compared to the PClass of the passenger on Survival

# %%
from sklearn.ensemble import RandomForestClassifier
X=trainML[['SibSp', 'Parch',
       'Fare', 'FamilyCount']].values # Taking all the numerical values
y = trainML['Survived'].values
RF = RandomForestClassifier()
RF.fit(X, y)
# Make a prediction
y_predict = RF.predict(X)
y_predict[:10]
(y == y_predict).mean()
# Out:
# 0.8910891089108911

# %% [markdown]
# Random forest did a good job in predicting the survival with a 90% accuracy
